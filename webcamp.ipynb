# %%
import torch
import numpy as np
import cv2
import time
from ultralytics import RTDETR, YOLO
import supervision as sv
from supervision import BoundingBoxAnnotator

# %%
class YOLOClass:
    def __init__(self, capture_index):
        self.capture_index = capture_index
        self.device = torch.device('cuda') if torch.cuda.is_available() else torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu')
        print("Using device:", self.device)
        # self.model = REDETR('rtdetr-l.pt')
        # self.model = YOLO('yolov8n.pt')
        self.model = YOLO('runs/detect/train27/weights/last.pt')
        self.CLASS_NAMES_DITC = self.model.model.names
        print("Classes: ", self.CLASS_NAMES_DITC)
        self.box_annotator = sv.BoundingBoxAnnotator()
        self.label_annotator = sv.LabelAnnotator()

    def plot_bboxes(self, results, frame):
        # Extract the results
        boxes = results[0].boxes.cpu().numpy()
        class_id = boxes.cls
        conf = boxes.conf
        xyxy = boxes.xyxy
        
        class_id = class_id.astype(np.int32)

        # Filter out detections for person objects
        # person_indices = np.where(class_id == 0)[0]
        # person_boxes = xyxy[person_indices]
        # person_confidences = conf[person_indices]
        # person_class_ids = class_id[person_indices]

        # detections = sv.Detections(
        #     xyxy=person_boxes,
        #     confidence=person_confidences,
        #     class_id=person_class_ids
        # )

        detections = sv.Detections(
            xyxy=xyxy,
            confidence=conf,
            class_id=class_id
        )

        frame = self.label_annotator.annotate(
            frame,
            detections=detections
        )

        self.labels = [f"{self.CLASS_NAMES_DITC[class_id]} {confidence:.2f}" for xyxy, mask, confidence, class_id, tracker_id, data in detections]

        frame = self.box_annotator.annotate(frame, detections)

        return frame

        # Initialize colors for different classes
        # colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255)]  # Example colors for 3 classes

        # for i in range(len(xyxy)):
        #     x1, y1, x2, y2 = int(xyxy[i][0]), int(xyxy[i][1]), int(xyxy[i][2]), int(xyxy[i][3])
        #     confidence = conf[i]
        #     class_name = self.CLASS_NAMES_DITC[class_id[i]]

        # # Draw rectangle
        # cv2.rectangle(frame, (x1, y1), (x2, y2), colors[class_id[i]], 2)

        # # Display class name and confidence
        # cv2.putText(frame, f"{class_name} {confidence:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, colors[class_id[i]], 2)

        # return frame
    
    def __call__(self):
        cap = cv2.VideoCapture(self.capture_index)
        assert cap.isOpened(), f"Failed to open camera"
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

        while cap.isOpened():
            start_time = time.perf_counter()
            ret, frame = cap.read()
            results = self.model.predict(frame)
            frame = self.plot_bboxes(results, frame)
            end_time = time.perf_counter()
            fps = 1 / (end_time - start_time)
            print(f"FPS: {fps:.2f}")

            cv2.putText(frame, f"{fps:.2f} FPS", (20, 70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 2)

            cv2.imshow('DETR', frame)

            if cv2.waitKey(1) == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()

    def train(self, config_file_path, epochs=1, imagesize=None, device="cpu", verbose=False):
        self.model.train(data=config_file_path, epochs=epochs, imgsz=imagesize, device=device, batch=-1, verbose=verbose)

# %%
yolo_detector = YOLOClass(1)
# Out:
# Using device: mps
# Classes:  {0: 'cross', 1: 'skyward', 2: 't-pose'}

# %%
yolo_detector.train(config_file_path="data.yaml", epochs=10, imagesize=640, device="mps", verbose=True)

# %%
yolo_detector()
# Out:
# 2024-04-03 11:23:24.485 python[54007:422182] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 384x640 (no detections), 84.9ms
# Speed: 2.2ms preprocess, 84.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 4.08
#
# 0: 384x640 1 cross, 60.5ms
# Speed: 1.2ms preprocess, 60.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.38
#
# 0: 384x640 1 cross, 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.47
#
# 0: 384x640 1 cross, 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.64
#
# 0: 384x640 1 cross, 68.3ms
# Speed: 1.5ms preprocess, 68.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.42
#
# 0: 384x640 1 cross, 59.3ms
# Speed: 1.3ms preprocess, 59.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 14.07
#
# 0: 384x640 1 cross, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.81
#
# 0: 384x640 1 cross, 53.6ms
# Speed: 1.2ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.83
#
# 0: 384x640 1 cross, 47.2ms
# Speed: 1.4ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.75
#
# 0: 384x640 1 cross, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 21.28
#
# 0: 384x640 1 cross, 48.9ms
# Speed: 1.3ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.10
#
# 0: 384x640 1 cross, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.64
#
# 0: 384x640 1 cross, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.09
#
# 0: 384x640 1 cross, 59.9ms
# Speed: 1.2ms preprocess, 59.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.41
#
# 0: 384x640 1 cross, 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.20
#
# 0: 384x640 1 cross, 45.9ms
# Speed: 1.1ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.50
#
# 0: 384x640 (no detections), 44.8ms
# Speed: 1.6ms preprocess, 44.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.69
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 2.1ms preprocess, 49.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.02
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.4ms preprocess, 47.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.32
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.21
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 1.8ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.30
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.2ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.81
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.1ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.70
#
# 0: 384x640 (no detections), 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 20.64
#
# 0: 384x640 (no detections), 37.2ms
# Speed: 1.2ms preprocess, 37.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 22.31
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 1.3ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.93
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 11.2ms preprocess, 46.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 14.15
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.15
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.46
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 2.0ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.75
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.1ms preprocess, 47.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.68
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.67
#
# 0: 384x640 (no detections), 44.7ms
# Speed: 1.8ms preprocess, 44.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.15
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.20
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.46
#
# 0: 384x640 1 skyward, 51.9ms
# Speed: 1.8ms preprocess, 51.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.08
#
# 0: 384x640 1 skyward, 50.8ms
# Speed: 1.5ms preprocess, 50.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.21
#
# 0: 384x640 1 skyward, 51.7ms
# Speed: 1.5ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.60
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.4ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.73
#
# 0: 384x640 1 skyward, 52.6ms
# Speed: 1.5ms preprocess, 52.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.63
#
# 0: 384x640 1 skyward, 48.1ms
# Speed: 1.8ms preprocess, 48.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.08
#
# 0: 384x640 1 skyward, 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.31
#
# 0: 384x640 1 skyward, 51.3ms
# Speed: 1.6ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.00
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.53
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.3ms preprocess, 46.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.67
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 1.8ms preprocess, 48.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.87
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 1.8ms preprocess, 45.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.60
#
# 0: 384x640 (no detections), 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.04
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 2.1ms preprocess, 55.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.55
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.09
#
# 0: 384x640 (no detections), 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.83
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.3ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.91
#
# 0: 384x640 1 cross, 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.70
#
# 0: 384x640 1 cross, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.32
#
# 0: 384x640 1 cross, 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.51
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.52
#
# 0: 384x640 1 cross, 48.4ms
# Speed: 1.7ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.96
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.19
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.92
#
# 0: 384x640 (no detections), 48.4ms
# Speed: 1.2ms preprocess, 48.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.29
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.79
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.3ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.05
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 1.6ms preprocess, 51.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.25
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 1.3ms preprocess, 48.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.18
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.98
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.03
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 1.2ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.43
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.0ms preprocess, 48.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.75
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.5ms preprocess, 52.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.77
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.33
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.81
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.4ms preprocess, 48.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.86
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 1.3ms preprocess, 48.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.85
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 2.1ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.93
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 1.5ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.70
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.1ms preprocess, 48.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.82
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.13
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.29
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 1.1ms preprocess, 40.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.18
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.0ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.12
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.3ms preprocess, 46.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.05
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.92
#
# 0: 384x640 (no detections), 75.2ms
# Speed: 0.9ms preprocess, 75.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.01
#
# 0: 384x640 (no detections), 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.34
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.87
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.07
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.74
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.77
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.19
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 0.9ms preprocess, 46.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.29
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.0ms preprocess, 54.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.81
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.42
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 1.4ms preprocess, 49.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.68
#
# 0: 384x640 (no detections), 51.4ms
# Speed: 1.6ms preprocess, 51.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.94
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.2ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.75
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 1.7ms preprocess, 49.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.18
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 1.3ms preprocess, 50.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.61
#
# 0: 384x640 (no detections), 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.96
#
# 0: 384x640 (no detections), 58.2ms
# Speed: 2.1ms preprocess, 58.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.86
#
# 0: 384x640 1 t-pose, 51.5ms
# Speed: 1.4ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.11
#
# 0: 384x640 1 t-pose, 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.27
#
# 0: 384x640 1 t-pose, 57.4ms
# Speed: 1.2ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.96
#
# 0: 384x640 1 t-pose, 51.4ms
# Speed: 1.3ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.64
#
# 0: 384x640 1 t-pose, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.52
#
# 0: 384x640 1 t-pose, 55.1ms
# Speed: 1.3ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.47
#
# 0: 384x640 1 t-pose, 53.0ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.03
#
# 0: 384x640 1 t-pose, 48.3ms
# Speed: 1.4ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.30
#
# 0: 384x640 1 t-pose, 47.4ms
# Speed: 1.1ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.87
#
# 0: 384x640 1 t-pose, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.41
#
# 0: 384x640 1 t-pose, 49.8ms
# Speed: 1.3ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.02
#
# 0: 384x640 1 t-pose, 56.9ms
# Speed: 1.3ms preprocess, 56.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.83
#
# 0: 384x640 1 t-pose, 48.0ms
# Speed: 1.0ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.24
#
# 0: 384x640 1 t-pose, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.12
#
# 0: 384x640 1 t-pose, 48.0ms
# Speed: 1.0ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.25
#
# 0: 384x640 1 t-pose, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 20.24
#
# 0: 384x640 1 t-pose, 47.7ms
# Speed: 1.1ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.59
#
# 0: 384x640 1 t-pose, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.50
#
# 0: 384x640 1 t-pose, 54.9ms
# Speed: 1.1ms preprocess, 54.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.04
#
# 0: 384x640 1 t-pose, 50.9ms
# Speed: 1.1ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.31
#
# 0: 384x640 1 t-pose, 48.9ms
# Speed: 1.4ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.79
#
# 0: 384x640 1 t-pose, 52.8ms
# Speed: 1.1ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.46
#
# 0: 384x640 1 t-pose, 59.7ms
# Speed: 1.0ms preprocess, 59.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.88
#
# 0: 384x640 1 t-pose, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.42
#
# 0: 384x640 1 t-pose, 53.0ms
# Speed: 1.3ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.14
#
# 0: 384x640 1 t-pose, 53.6ms
# Speed: 1.1ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.65
#
# 0: 384x640 1 t-pose, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.85
#
# 0: 384x640 1 t-pose, 52.0ms
# Speed: 1.6ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.54
#
# 0: 384x640 1 t-pose, 51.4ms
# Speed: 1.1ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.13
#
# 0: 384x640 1 t-pose, 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.33
#
# 0: 384x640 1 t-pose, 50.7ms
# Speed: 1.2ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.20
#
# 0: 384x640 1 t-pose, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.90
#
# 0: 384x640 1 t-pose, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.18
#
# 0: 384x640 1 t-pose, 69.0ms
# Speed: 8.7ms preprocess, 69.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 8.86
#
# 0: 384x640 1 t-pose, 51.9ms
# Speed: 1.3ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.41
#
# 0: 384x640 1 t-pose, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.04
#
# 0: 384x640 1 t-pose, 50.9ms
# Speed: 0.9ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.61
#
# 0: 384x640 1 t-pose, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.00
#
# 0: 384x640 1 t-pose, 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.21
#
# 0: 384x640 1 t-pose, 51.5ms
# Speed: 1.3ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.44
#
# 0: 384x640 1 t-pose, 49.1ms
# Speed: 1.5ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.96
#
# 0: 384x640 1 t-pose, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.83
#
# 0: 384x640 1 t-pose, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.99
#
# 0: 384x640 1 t-pose, 50.0ms
# Speed: 1.2ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.60
#
# 0: 384x640 1 t-pose, 56.9ms
# Speed: 1.1ms preprocess, 56.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.88
#
# 0: 384x640 1 t-pose, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.46
#
# 0: 384x640 1 t-pose, 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.23
#
# 0: 384x640 1 t-pose, 50.4ms
# Speed: 1.4ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.23
#
# 0: 384x640 1 t-pose, 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.89
#
# 0: 384x640 1 t-pose, 47.7ms
# Speed: 1.9ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.05
#
# 0: 384x640 1 t-pose, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 22.29
#
# 0: 384x640 1 t-pose, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.86
#
# 0: 384x640 1 t-pose, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.83
#
# 0: 384x640 1 skyward, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.96
#
# 0: 384x640 1 skyward, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.96
#
# 0: 384x640 1 skyward, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.48
#
# 0: 384x640 1 skyward, 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.63
#
# 0: 384x640 1 skyward, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 20.00
#
# 0: 384x640 1 skyward, 52.8ms
# Speed: 0.9ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.70
#
# 0: 384x640 1 skyward, 51.9ms
# Speed: 0.9ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.85
#
# 0: 384x640 1 skyward, 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.86
#
# 0: 384x640 1 skyward, 65.7ms
# Speed: 1.0ms preprocess, 65.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.96
#
# 0: 384x640 1 skyward, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 14.48
#
# 0: 384x640 1 skyward, 48.0ms
# Speed: 1.3ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.10
#
# 0: 384x640 1 skyward, 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.99
#
# 0: 384x640 1 skyward, 52.3ms
# Speed: 1.6ms preprocess, 52.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.57
#
# 0: 384x640 1 skyward, 47.4ms
# Speed: 1.0ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.56
#
# 0: 384x640 1 skyward, 52.6ms
# Speed: 1.7ms preprocess, 52.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.96
#
# 0: 384x640 1 skyward, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.50
#
# 0: 384x640 1 skyward, 49.0ms
# Speed: 0.9ms preprocess, 49.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.62
#
# 0: 384x640 1 skyward, 52.3ms
# Speed: 1.3ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.34
#
# 0: 384x640 1 skyward, 49.2ms
# Speed: 1.4ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.10
#
# 0: 384x640 1 skyward, 52.6ms
# Speed: 1.2ms preprocess, 52.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.37
#
# 0: 384x640 1 skyward, 48.5ms
# Speed: 1.0ms preprocess, 48.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.22
#
# 0: 384x640 1 skyward, 53.0ms
# Speed: 1.7ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.91
#
# 0: 384x640 1 skyward, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.07
#
# 0: 384x640 1 skyward, 75.0ms
# Speed: 1.2ms preprocess, 75.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.23
#
# 0: 384x640 1 skyward, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.93
#
# 0: 384x640 1 skyward, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.91
#
# 0: 384x640 1 skyward, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.36
#
# 0: 384x640 1 skyward, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.88
#
# 0: 384x640 1 skyward, 53.5ms
# Speed: 0.9ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.09
#
# 0: 384x640 1 skyward, 48.9ms
# Speed: 1.1ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.44
#
# 0: 384x640 1 skyward, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.99
#
# 0: 384x640 1 skyward, 51.3ms
# Speed: 1.3ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.74
#
# 0: 384x640 1 skyward, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.97
#
# 0: 384x640 1 skyward, 41.5ms
# Speed: 1.2ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 20.06
#
# 0: 384x640 1 skyward, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.38
#
# 0: 384x640 1 skyward, 41.6ms
# Speed: 1.2ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.58
#
# 0: 384x640 1 skyward, 47.6ms
# Speed: 1.1ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.17
#
# 0: 384x640 1 skyward, 50.5ms
# Speed: 1.3ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.16
#
# 0: 384x640 1 skyward, 56.6ms
# Speed: 1.3ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.95
#
# 0: 384x640 1 skyward, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.28
#
# 0: 384x640 1 skyward, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.48
#
# 0: 384x640 1 skyward, 52.1ms
# Speed: 1.2ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.38
#
# 0: 384x640 1 skyward, 48.8ms
# Speed: 1.2ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.29
#
# 0: 384x640 1 skyward, 50.3ms
# Speed: 1.6ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.25
#
# 0: 384x640 1 skyward, 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.08
#
# 0: 384x640 1 skyward, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.54
#
# 0: 384x640 1 skyward, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.80
#
# 0: 384x640 1 skyward, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.19
#
# 0: 384x640 1 skyward, 54.0ms
# Speed: 1.7ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.63
#
# 0: 384x640 1 skyward, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.73
#
# 0: 384x640 1 skyward, 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.48
#
# 0: 384x640 1 skyward, 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.81
#
# 0: 384x640 1 skyward, 53.6ms
# Speed: 1.2ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.36
#
# 0: 384x640 1 skyward, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.03
#
# 0: 384x640 1 skyward, 51.9ms
# Speed: 1.2ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.71
#
# 0: 384x640 1 skyward, 49.5ms
# Speed: 1.7ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.83
#
# 0: 384x640 1 skyward, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.81
#
# 0: 384x640 1 skyward, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.57
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.30
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.50
#
# 0: 384x640 (no detections), 47.8ms
# Speed: 1.4ms preprocess, 47.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.31
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 21.28
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 20.16
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.3ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.94
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.78
#
# 0: 384x640 (no detections), 69.4ms
# Speed: 1.0ms preprocess, 69.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.16
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 0.9ms preprocess, 50.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.07
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.47
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.3ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.52
#
# 0: 384x640 (no detections), 60.9ms
# Speed: 1.5ms preprocess, 60.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.78
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.2ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.06
#
# 0: 384x640 (no detections), 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.14
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.11
#
# 0: 384x640 (no detections), 49.0ms
# Speed: 1.3ms preprocess, 49.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.83
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 1.7ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.81
#
# 0: 384x640 1 t-pose, 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.11
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.03
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.1ms preprocess, 45.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.20
#
# 0: 384x640 (no detections), 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.68
#
# 0: 384x640 (no detections), 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.95
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 1.3ms preprocess, 49.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.62
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.62
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.49
#
# 0: 384x640 (no detections), 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.91
#
# 0: 384x640 (no detections), 54.7ms
# Speed: 1.1ms preprocess, 54.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.13
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.2ms preprocess, 46.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.90
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.24
#
# 0: 384x640 (no detections), 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.40
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 1.2ms preprocess, 48.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 14.30
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 1.7ms preprocess, 48.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.72
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.27
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.5ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.68
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.4ms preprocess, 48.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.24
#
# 0: 384x640 (no detections), 49.0ms
# Speed: 1.2ms preprocess, 49.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.93
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.3ms preprocess, 50.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.48
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.37
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.3ms preprocess, 54.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.59
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.91
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 1.4ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.29
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.7ms preprocess, 53.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.91
#
# 0: 384x640 (no detections), 52.7ms
# Speed: 1.0ms preprocess, 52.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.17
#
# 0: 384x640 (no detections), 52.7ms
# Speed: 1.2ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.59
#
# 0: 384x640 (no detections), 53.8ms
# Speed: 1.3ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.64
#
# 0: 384x640 (no detections), 70.5ms
# Speed: 1.2ms preprocess, 70.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.81
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.91
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.3ms preprocess, 48.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.72
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.97
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 0.9ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.17
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.55
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.25
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.3ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.25
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.0ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.66
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.96
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 1.6ms preprocess, 48.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.10
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.1ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.16
#
# 0: 384x640 (no detections), 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.08
#
# 0: 384x640 (no detections), 50.5ms
# Speed: 1.2ms preprocess, 50.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.84
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.75
#
# 0: 384x640 (no detections), 49.0ms
# Speed: 1.4ms preprocess, 49.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.93
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 1.4ms preprocess, 51.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.41
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.8ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.31
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 1.1ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.12
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.0ms preprocess, 55.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.29
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.17
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.1ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.50
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.49
#
# 0: 384x640 (no detections), 50.1ms
# Speed: 1.1ms preprocess, 50.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.52
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 1.7ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.72
#
# 0: 384x640 (no detections), 58.2ms
# Speed: 0.9ms preprocess, 58.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.72
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.03
#
# 0: 384x640 (no detections), 62.2ms
# Speed: 1.3ms preprocess, 62.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.29
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.38
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.22
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.44
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.6ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.31
#
# 0: 384x640 (no detections), 81.6ms
# Speed: 1.0ms preprocess, 81.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 8.91
#
# 0: 384x640 (no detections), 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.24
#
# 0: 384x640 (no detections), 51.8ms
# Speed: 1.2ms preprocess, 51.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.60
#
# 0: 384x640 (no detections), 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.20
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.01
#
# 0: 384x640 (no detections), 57.7ms
# Speed: 1.0ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.13
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.62
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.80
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.56
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.1ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.62
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 1.4ms preprocess, 47.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.68
#
# 0: 384x640 (no detections), 58.1ms
# Speed: 1.3ms preprocess, 58.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.94
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.11
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.3ms preprocess, 50.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.54
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.94
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.37
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 1.4ms preprocess, 51.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.75
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.1ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.52
#
# 0: 384x640 1 t-pose, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.86
#
# 0: 384x640 1 t-pose, 38.8ms
# Speed: 1.2ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 22.32
#
# 0: 384x640 1 t-pose, 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.64
#
# 0: 384x640 1 t-pose, 39.8ms
# Speed: 1.2ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.15
#
# 0: 384x640 1 t-pose, 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.52
#
# 0: 384x640 1 t-pose, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.66
#
# 0: 384x640 1 t-pose, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 20.16
#
# 0: 384x640 1 t-pose, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.12
#
# 0: 384x640 1 t-pose, 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.86
#
# 0: 384x640 1 t-pose, 56.4ms
# Speed: 1.0ms preprocess, 56.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.33
#
# 0: 384x640 1 t-pose, 53.0ms
# Speed: 1.3ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.20
#
# 0: 384x640 1 t-pose, 53.5ms
# Speed: 1.2ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.57
#
# 0: 384x640 1 t-pose, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.25
#
# 0: 384x640 1 t-pose, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.54
#
# 0: 384x640 1 t-pose, 49.6ms
# Speed: 1.5ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.58
#
# 0: 384x640 1 t-pose, 45.7ms
# Speed: 1.6ms preprocess, 45.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.34
#
# 0: 384x640 1 skyward, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.94
#
# 0: 384x640 1 skyward, 54.5ms
# Speed: 1.6ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.28
#
# 0: 384x640 1 skyward, 47.6ms
# Speed: 1.1ms preprocess, 47.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.90
#
# 0: 384x640 1 skyward, 46.5ms
# Speed: 1.0ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 19.58
#
# 0: 384x640 1 skyward, 47.4ms
# Speed: 1.0ms preprocess, 47.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.76
#
# 0: 384x640 1 skyward, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.98
#
# 0: 384x640 1 skyward, 53.8ms
# Speed: 1.3ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.34
#
# 0: 384x640 1 skyward, 53.3ms
# Speed: 1.0ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.80
#
# 0: 384x640 1 skyward, 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.97
#
# 0: 384x640 1 skyward, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.94
#
# 0: 384x640 1 skyward, 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.49
#
# 0: 384x640 1 skyward, 50.5ms
# Speed: 1.3ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.01
#
# 0: 384x640 1 skyward, 56.3ms
# Speed: 1.5ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.71
#
# 0: 384x640 1 skyward, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.45
#
# 0: 384x640 1 skyward, 58.4ms
# Speed: 1.1ms preprocess, 58.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.11
#
# 0: 384x640 1 skyward, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.75
#
# 0: 384x640 1 skyward, 51.4ms
# Speed: 1.1ms preprocess, 51.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.72
#
# 0: 384x640 1 skyward, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.76
#
# 0: 384x640 2 skywards, 50.7ms
# ...
# Speed: 1.8ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.22
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.75
#
# 0: 384x640 (no detections), 57.4ms
# Speed: 2.0ms preprocess, 57.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.78
#
# 0: 384x640 (no detections), 48.4ms
# Speed: 1.7ms preprocess, 48.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.44
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.5ms preprocess, 53.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.26
#
# 0: 384x640 (no detections), 91.1ms
# Speed: 1.4ms preprocess, 91.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 8.21
#
# 0: 384x640 (no detections), 56.3ms
# Speed: 1.3ms preprocess, 56.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.21
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.8ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.38
#
# 0: 384x640 (no detections), 57.3ms
# Speed: 1.7ms preprocess, 57.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.42
#
# 0: 384x640 (no detections), 69.5ms
# Speed: 2.4ms preprocess, 69.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.32
#
# 0: 384x640 (no detections), 58.0ms
# Speed: 1.6ms preprocess, 58.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 14.11
#
# 0: 384x640 (no detections), 56.9ms
# Speed: 1.6ms preprocess, 56.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.26
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 3.5ms preprocess, 69.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.01
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.6ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.94
#
# 0: 384x640 (no detections), 74.8ms
# Speed: 1.9ms preprocess, 74.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.51
#
# 0: 384x640 (no detections), 106.0ms
# Speed: 1.7ms preprocess, 106.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 8.45
#
# 0: 384x640 (no detections), 59.0ms
# Speed: 1.6ms preprocess, 59.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.13
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.50
#
# 0: 384x640 (no detections), 60.7ms
# Speed: 1.7ms preprocess, 60.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.23
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.87
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.20
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 1.8ms preprocess, 50.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.51
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 1.8ms preprocess, 56.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.13
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.55
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.41
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 1.8ms preprocess, 57.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.98
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 3.2ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.00
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.62
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 1.3ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.46
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.5ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.44
#
# 0: 384x640 (no detections), 76.6ms
# Speed: 1.6ms preprocess, 76.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.43
#
# 0: 384x640 (no detections), 67.7ms
# Speed: 1.8ms preprocess, 67.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.37
#
# 0: 384x640 (no detections), 57.9ms
# Speed: 1.4ms preprocess, 57.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.74
#
# 0: 384x640 (no detections), 74.8ms
# Speed: 7.3ms preprocess, 74.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.20
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.7ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.43
#
# 0: 384x640 (no detections), 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.63
#
# 0: 384x640 (no detections), 58.0ms
# Speed: 1.5ms preprocess, 58.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.67
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.14
#
# 0: 384x640 (no detections), 81.8ms
# Speed: 1.4ms preprocess, 81.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 8.82
#
# 0: 384x640 (no detections), 59.6ms
# Speed: 1.5ms preprocess, 59.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.56
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.89
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.95
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.70
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.83
#
# 0: 384x640 (no detections), 46.5ms
# Speed: 1.4ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.77
#
# 0: 384x640 (no detections), 62.2ms
# Speed: 1.5ms preprocess, 62.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.77
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.7ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.84
#
# 0: 384x640 (no detections), 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.18
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.35
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.7ms preprocess, 54.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.66
#
# 0: 384x640 (no detections), 44.4ms
# Speed: 1.6ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.70
#
# 0: 384x640 (no detections), 51.8ms
# Speed: 1.9ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 17.27
#
# 0: 384x640 (no detections), 79.0ms
# Speed: 1.5ms preprocess, 79.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.16
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 2.7ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.25
#
# 0: 384x640 (no detections), 61.2ms
# Speed: 1.3ms preprocess, 61.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.28
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.5ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.30
#
# 0: 384x640 (no detections), 54.7ms
# Speed: 1.8ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.87
#
# 0: 384x640 (no detections), 62.9ms
# Speed: 1.9ms preprocess, 62.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.77
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.8ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.44
#
# 0: 384x640 (no detections), 95.6ms
# Speed: 1.9ms preprocess, 95.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 8.13
#
# 0: 384x640 (no detections), 56.8ms
# Speed: 1.4ms preprocess, 56.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.88
#
# 0: 384x640 (no detections), 67.0ms
# Speed: 1.4ms preprocess, 67.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.74
#
# 0: 384x640 (no detections), 58.9ms
# Speed: 1.4ms preprocess, 58.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.32
#
# 0: 384x640 (no detections), 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.15
#
# 0: 384x640 (no detections), 63.9ms
# Speed: 1.8ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.13
#
# 0: 384x640 (no detections), 64.2ms
# Speed: 1.6ms preprocess, 64.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.01
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 1.5ms preprocess, 85.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.40
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 1.7ms preprocess, 58.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.39
#
# 0: 384x640 (no detections), 70.7ms
# Speed: 2.5ms preprocess, 70.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.06
#
# 0: 384x640 (no detections), 64.0ms
# Speed: 1.8ms preprocess, 64.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.68
#
# 0: 384x640 (no detections), 56.9ms
# Speed: 1.4ms preprocess, 56.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.20
#
# 0: 384x640 (no detections), 76.4ms
# Speed: 1.3ms preprocess, 76.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.67
#
# 0: 384x640 (no detections), 56.3ms
# Speed: 1.8ms preprocess, 56.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 15.04
#
# 0: 384x640 (no detections), 68.9ms
# Speed: 1.6ms preprocess, 68.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.49
#
# 0: 384x640 (no detections), 59.8ms
# Speed: 1.5ms preprocess, 59.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.64
#
# 0: 384x640 (no detections), 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.80
#
# 0: 384x640 (no detections), 61.4ms
# Speed: 1.3ms preprocess, 61.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.98
#
# 0: 384x640 (no detections), 60.9ms
# Speed: 1.6ms preprocess, 60.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.93
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 4.8ms preprocess, 69.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.13
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.3ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 18.60
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.20
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.13
#
# 0: 384x640 (no detections), 99.4ms
# Speed: 1.7ms preprocess, 99.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 7.58
#
# 0: 384x640 (no detections), 62.3ms
# Speed: 1.6ms preprocess, 62.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.71
#
# 0: 384x640 (no detections), 60.1ms
# Speed: 1.5ms preprocess, 60.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.12
#
# 0: 384x640 (no detections), 56.7ms
# Speed: 1.4ms preprocess, 56.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.73
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 1.5ms preprocess, 57.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.76
#
# 0: 384x640 (no detections), 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.23
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 1.6ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.84
#
# 0: 384x640 (no detections), 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.43
#
# 0: 384x640 (no detections), 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.68
#
# 0: 384x640 (no detections), 61.3ms
# Speed: 1.6ms preprocess, 61.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.49
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.19
#
# 0: 384x640 (no detections), 72.1ms
# Speed: 4.5ms preprocess, 72.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 9.61
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.00
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.05
#
# 0: 384x640 (no detections), 82.6ms
# Speed: 2.5ms preprocess, 82.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 8.81
#
# 0: 384x640 (no detections), 59.1ms
# Speed: 1.7ms preprocess, 59.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.87
#
# 0: 384x640 (no detections), 58.9ms
# Speed: 1.3ms preprocess, 58.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.05
#
# 0: 384x640 (no detections), 64.4ms
# Speed: 1.4ms preprocess, 64.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.31
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.80
#
# 0: 384x640 (no detections), 64.0ms
# Speed: 1.2ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.20
#
# 0: 384x640 (no detections), 108.3ms
# Speed: 1.8ms preprocess, 108.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 7.81
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 2.3ms preprocess, 51.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 16.53
#
# 0: 384x640 (no detections), 49.7ms
# Speed: 1.5ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 12.47
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 3.5ms preprocess, 55.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 10.82
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 1.6ms preprocess, 50.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 13.27
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.5ms preprocess, 54.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 11.41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 yolo_detector()
#
# Cell In[2], line 76, in YOLOClass.__call__(self)
#      74 while cap.isOpened():
#      75     start_time = time.perf_counter()
# ---> 76     ret, frame = cap.read()
#      77     results = self.model.predict(frame)
#      78     frame = self.plot_bboxes(results, frame)
#
# KeyboardInterrupt:
